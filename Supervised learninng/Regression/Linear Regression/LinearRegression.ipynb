# %%
import numpy as np
import matplotlib.pyplot as plt


# Set the seed for reproducibility
np.random.seed(42)

# Number of samples
num_samples = 100

# Generate random x values (features)
x_train = 2 * np.random.rand(num_samples, 1)

# Generate corresponding y values with a linear relationship (y = 4 + 3x + noise)
true_slope = 3
true_intercept = 4
noise = np.random.randn(num_samples, 1)

y_train = true_intercept + true_slope * x_train + noise

# Plotting the data
plt.figure(figsize = (8, 5))
plt.scatter(x_train, y_train, color = "blue", label = "Training data", alpha = 0.7)
plt.title("Dummy Linear Regression Data")
plt.xlabel("x_train")
plt.ylabel("y_train")
plt.legend()
plt.grid(True)
plt.show()

print("Features shape is:", x_train.shape)
print("Target shape is:", y_train.shape)
# Out:
# Features shape is: (100, 1)
# Target shape is: (100, 1)

# %%
# #parameters
# w=0
# b=0
# #learning rate
# alpha=0.1
# iterations=100
# #number of training samples
# m=len(x_train)
# cost_history=[]
# for i in range(iterations):
#     y_pred = []
#     loss = []
#     dw_ = []
#     db_ = []
 
#     for j in range(m):    
#         y_ = w * x_train[j] + b
#         y_pred.append(y_)

#         error = (y_ - y_train[j]) ** 2
#         loss.append(error)
    
        
#         # derivatives
#         dw_.append((y_ - y_train[j]) * x_train[j])
#         db_.append(y_ - y_train[j])
        
    
#     #cost fuction
#     cost = (1/(2*m)) * sum(loss)
#     #store cost
#     cost_history.append(cost)
    

#     # derivatives
#     dw = (1/m) * sum(dw_)
#     db = (1/m) * sum(db_)

#     # # update parameters
#     w = w - alpha * dw
#     b = b - alpha * db
    
# # final prediction after training
# y_pred = w * x_train + b

# #graph 1
# plt.figure(figsize=(8,5))
# plt.scatter(x_train, y_train, color='blue', label='Actual Data')
# plt.plot(x_train,y_pred,color='r',label='prediction line')
# plt.xlabel('x')
# plt.ylabel('y')
# plt.grid(True)
# plt.show()
# #graph 2
# plt.plot(range(iterations),cost_history)
# plt.xlabel('iteration')
# plt.ylabel('cost')
# plt.grid(True)
# plt.show()

# %%
# #parameters
# w=0
# b=0
# #learning rate
# alpha=0.1
# iterations=100
# #number of training samples
# m=len(x_train)
# sum_x = 0
# sum_y = 0
# sum_xy = 0
# sum_x2 = 0
    
# for i in range(m):
#     sum_x = sum_x + x_train[i]
#     sum_y = sum_y + y_train[i]
#     sum_xy = sum_xy + (x_train[i] * y_train[i])
#     sum_x2 = sum_x2 + (x_train[i] ** 2)

# # Calculate w using formula
# w = ((m * sum_xy) - (sum_x * sum_y)) / ((m * sum_x2) - (sum_x ** 2))

# # Calculate b using formula
# b = (sum_y - (w * sum_x)) / m

# # Print results
# print("Weight (w) =", w)
# print("Bias (b) =", b)
# Out:
# Weight (w) = [2.77011339]
# Bias (b) = [4.21509616]

# %%
m=len(x_train)
sum_x =np.sum(x_train)
sum_y =np.sum(y_train)
sum_xy = np.sum(x_train * y_train)
sum_x2 = np.sum(x_train ** 2)
# Calculate w using formula
w = ((m * sum_xy) - (sum_x * sum_y)) / ((m * sum_x2) - (sum_x ** 2))

# Calculate b using formula
b = (sum_y - (w * sum_x)) / m

# Print results
print("Weight (w) =", w)
print("Bias (b) =", b)
# Out:
# Weight (w) = 2.7701133864384864
# Bias (b) = 4.2150961575467445
